# %% [markdown]
# <a href="https://colab.research.google.com/github/irawan555/MachineLearningTasks/blob/main/13thWeekTasks/BAB%204/Irawan_Mardiansyah_1103210174_Sharing_pretrained_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Irawan Mardiansyah
#
# NIM : 1103210174
#
# Kelas : TK4504
#
# Lecture : 13

# %% [markdown]
# # Sharing pretrained models

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# !apt install git-lfs
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !pip install transformers[torch] accelerate -U

# %%
# !git config --global user.email "irawanmardiansyah94@gmail.com"
# !git config --global user.name "Irawan"

# %%
# Mengimpor fungsi notebook_login dari pustaka huggingface_hub
from huggingface_hub import notebook_login

# Melakukan login ke Hugging Face Hub dari notebook atau lingkungan Jupyter
notebook_login()

# %%
# Mengimpor fungsi notebook_login dari pustaka huggingface_hub
from huggingface_hub import notebook_login

# Melakukan login ke Hugging Face Hub dari notebook atau lingkungan Jupyter
notebook_login()

# %%
# !pip install transformers[torch]

# %%
# Mengimpor kelas-kelas yang diperlukan dari pustaka Transformers
from transformers import AutoModelForMaskedLM, AutoTokenizer

# Menentukan nama checkpoint untuk model yang akan digunakan
checkpoint = "camembert-base"

# Memuat model untuk Masked Language Modeling (MLM) dari checkpoint yang telah ditentukan
model = AutoModelForMaskedLM.from_pretrained(checkpoint)

# Memuat tokenizer dari checkpoint yang telah ditentukan
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# ...

# %%
# Mengimpor fungsi-fungsi yang diperlukan dari pustaka huggingface_hub
from huggingface_hub import (

    # Fungsi untuk login ke akun Hugging Face
    login,

    # Fungsi untuk logout dari akun Hugging Face
    logout,

    # Fungsi untuk mendapatkan informasi tentang pengguna yang sedang login
    whoami,

    # Fungsi untuk membuat repositori baru di Hugging Face Hub
    create_repo,

    # Fungsi untuk menghapus repositori di Hugging Face Hub
    delete_repo,

    # Fungsi untuk mengubah visibilitas repositori (publik/privat)
    update_repo_visibility,

    # Fungsi untuk mendapatkan daftar model yang tersedia di Hugging Face Hub
    list_models,

    # Fungsi untuk mendapatkan daftar dataset yang tersedia di Hugging Face Hub
    list_datasets,

    # Fungsi untuk mendapatkan daftar metrik yang tersedia di Hugging Face Hub
    list_metrics,

    # Fungsi untuk mendapatkan daftar file yang ada di repositori
    list_repo_files,

    # Fungsi untuk mengunggah file ke repositori di Hugging Face Hub
    upload_file,

    # Fungsi untuk menghapus file dari repositori di Hugging Face Hub
    delete_file,
)

# %%
# Mengimpor kelas-kelas yang diperlukan dari pustaka Transformers
from transformers import AutoModelForMaskedLM, AutoTokenizer

# Menentukan checkpoint dari model pra-terlatih yang akan digunakan
checkpoint = "camembert-base"

# Memuat model pra-terlatih untuk Masked Language Modeling dari checkpoint yang ditentukan
model = AutoModelForMaskedLM.from_pretrained(checkpoint)

# Memuat tokenizer yang sesuai dengan model pra-terlatih dari checkpoint yang sama
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# Menyimpan model yang telah dimuat ke folder yang ditentukan
model.save_pretrained("<path_to_dummy_folder>")

# Menyimpan tokenizer yang telah dimuat ke folder yang ditentukan
tokenizer.save_pretrained("<path_to_dummy_folder>")
# Out:
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing CamembertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ('<path_to_dummy_folder>/tokenizer_config.json',
#  '<path_to_dummy_folder>/special_tokens_map.json',
#  '<path_to_dummy_folder>/sentencepiece.bpe.model',
#  '<path_to_dummy_folder>/added_tokens.json',
#  '<path_to_dummy_folder>/tokenizer.json')
